# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Loading a Dataset

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# Display a sample

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1730  3877-JRJIP    Male              0      No         No       1
# 895   0730-KOAVE    Male              0      No         No      30
# 3108  5056-FIMPT  Female              0      No        Yes      43
# 2435  9481-SFCQY  Female              0      No        Yes      14
# 5064  5673-TIYIB    Male              0      No         No       2
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1730          Yes               Yes             DSL             No  ...
# 895           Yes               Yes     Fiber optic            Yes  ...
# 3108          Yes                No     Fiber optic            Yes  ...
# 2435          Yes                No             DSL             No  ...
# 5064           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1730               No          No         Yes              No  Month-to-month
# 895                No          No          No             Yes  Month-to-month
# 3108               No         Yes         Yes             Yes        One year
# 2435              Yes          No         Yes              No  Month-to-month
# 5064              Yes         Yes          No              No  Month-to-month
#
#      PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 1730              Yes         Electronic check          59.85         59.85
# 895               Yes  Credit card (automatic)          94.30        2679.7
# 3108              Yes  Credit card (automatic)         106.00        4532.3
# 2435              Yes  Credit card (automatic)          59.80        824.85
# 5064              Yes  Credit card (automatic)          40.40         77.15
#
#      Churn
# 1730   Yes
# 895     No
# 3108    No
# 2435    No
# 5064   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Dataset Genaral Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# Data Preprocessing

# %%
df.drop('customerID',axis='columns',inplace=True)

# %% [markdown]
# Gender

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["gender"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Males Vs Females')
plt.xlabel('Gender', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Counts', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# Partner

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["Partner"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Yes Vs No')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df['Partner'] = df['Partner'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# Dependents

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["Dependents"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %%
df['Dependents'] = df['Dependents'].map({'No': 0, 'Yes': 1})

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["PhoneService"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %%
df['PhoneService'] = df['PhoneService'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# Multiple Lines

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
colors = ["#2B299B" , "#3B74C9" , "#85DFE3"]

plt.figure(figsize = (20, 6))

counts = df["MultipleLines"].value_counts()
explode = (0, 0.1  , 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Status')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
mapping_dict = {'No phone service': 0, 'No': 0, 'Yes': 1}

df['MultipleLines'] = df['MultipleLines'].map(mapping_dict)

# %% [markdown]
# Using Sklearn One Hot Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.InternetService = le.fit_transform(df.InternetService)

# %%
df.Contract = le.fit_transform(df.Contract)

# %%
df.PaymentMethod = le.fit_transform(df.PaymentMethod)

# %% [markdown]
# Displate another sample

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5624       0              1        1           0      62             1
# 6830       0              0        0           0      35             1
# 4905       1              0        1           1      58             1
# 6787       0              0        1           1      35             1
#
#       MultipleLines  InternetService       OnlineSecurity  \
# 5624              1                1                   No
# 6830              0                2  No internet service
# 4905              0                2  No internet service
# 6787              1                1                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 5624                  Yes                   No                   No
# 6830  No internet service  No internet service  No internet service
# 4905  No internet service  No internet service  No internet service
# 6787                  Yes                  Yes                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 5624                   No                  Yes         0              Yes
# 6830  No internet service  No internet service         2              Yes
# 4905  No internet service  No internet service         2              Yes
# 6787                  Yes                  Yes         0              Yes
#
#       PaymentMethod  MonthlyCharges TotalCharges Churn
# 5624              0           89.80      5629.55    No
# 6830              3           20.20        684.4    No
# 4905              3           19.85      1158.85    No
# 6787              2          109.95       3782.4    No

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df[col].replace({'Yes': 1,'No': 0},inplace=True)

# %% [markdown]
# Check the Null values

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull().sum()
# Out:
# np.int64(11)

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        1              0        1           1       0             0
# 753        0              0        0           1       0             1
# 936        1              0        1           1       0             1
# 1082       0              0        1           1       0             1
# 1340       1              0        1           1       0             0
# 3331       0              0        1           1       0             1
# 3826       0              0        1           1       0             1
# 4380       1              0        1           1       0             1
# 5218       0              0        1           1       0             1
# 6670       1              0        1           1       0             1
# 6754       0              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 488               0                0               1             0
# 753               0                2               0             0
# 936               0                0               1             1
# 1082              1                2               0             0
# 1340              0                0               1             1
# 3331              0                2               0             0
# 3826              1                2               0             0
# 4380              0                2               0             0
# 5218              0                2               0             0
# 6670              1                0               0             1
# 6754              1                0               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 488                  1            1            1                0         2
# 753                  0            0            0                0         2
# 936                  1            0            1                1         2
# 1082                 0            0            0                0         2
# 1340                 1            1            1                0         2
# 3331                 0            0            0                0         2
# 3826                 0            0            0                0         2
# 4380                 0            0            0                0         2
# 5218                 0            0            0                0         1
# 6670                 1            1            1                0         2
# 6754                 0            1            0                0         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges  Churn
# 488                  1              0           52.55                   0
# 753                  0              3           20.25                   0
# 936                  0              3           80.85                   0
# 1082                 0              3           25.75                   0
# 1340                 0              1           56.05                   0
# 3331                 0              3           19.85                   0
# 3826                 0              3           25.35                   0
# 4380                 0              3           20.00                   0
# 5218                 1              3           19.70                   0
# 6670                 0              3           73.35                   0
# 6754                 1              0           61.90                   0

# %%
df.shape
# Out:
# (7043, 20)

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 20)

# %% [markdown]
# Min Max Scaler

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df[cols_to_scale ].sample(5)
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 1726  0.408451        0.314925      0.164222
# 5555  0.971831        0.015423      0.156929
# 2841  0.028169        0.068159      0.007039
# 5328  0.760563        0.475622      0.397334
# 6619  0.112676        0.018905      0.025312

# %% [markdown]
# Dataset Final Summary

# %%
def summary(df):
    summary_df = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary_df['missing#'] = df.isna().sum()
    summary_df['missing%'] = (df.isna().sum())/len(df)
    summary_df['unique'] = df.nunique().values
    summary_df['count'] = df.count().values
    return summary_df

summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8bbf2_row0_col1, #T_8bbf2_row0_col2, #T_8bbf2_row0_col3, #T_8bbf2_row0_col4, #T_8bbf2_row1_col1, #T_8bbf2_row1_col2, #T_8bbf2_row1_col3, #T_8bbf2_row1_col4, #T_8bbf2_row2_col1, #T_8bbf2_row2_col2, #T_8bbf2_row2_col3, #T_8bbf2_row2_col4, #T_8bbf2_row3_col1, #T_8bbf2_row3_col2, #T_8bbf2_row3_col3, #T_8bbf2_row3_col4, #T_8bbf2_row4_col1, #T_8bbf2_row4_col2, #T_8bbf2_row4_col4, #T_8bbf2_row5_col1, #T_8bbf2_row5_col2, #T_8bbf2_row5_col3, #T_8bbf2_row5_col4, #T_8bbf2_row6_col1, #T_8bbf2_row6_col2, #T_8bbf2_row6_col3, #T_8bbf2_row6_col4, #T_8bbf2_row7_col1, #T_8bbf2_row7_col2, #T_8bbf2_row7_col3, #T_8bbf2_row7_col4, #T_8bbf2_row8_col1, #T_8bbf2_row8_col2, #T_8bbf2_row8_col3, #T_8bbf2_row8_col4, #T_8bbf2_row9_col1, #T_8bbf2_row9_col2, #T_8bbf2_row9_col3, #T_8bbf2_row9_col4, #T_8bbf2_row10_col1, #T_8bbf2_row10_col2, #T_8bbf2_row10_col3, #T_8bbf2_row10_col4, #T_8bbf2_row11_col1, #T_8bbf2_row11_col2, #T_8bbf2_row11_col3, #T_8bbf2_row11_col4, #T_8bbf2_row12_col1, #T_8bbf2_row12_col2, #T_8bbf2_row12_col3, #T_8bbf2_row12_col4, #T_8bbf2_row13_col1, #T_8bbf2_row13_col2, #T_8bbf2_row13_col3, #T_8bbf2_row13_col4, #T_8bbf2_row14_col1, #T_8bbf2_row14_col2, #T_8bbf2_row14_col3, #T_8bbf2_row14_col4, #T_8bbf2_row15_col1, #T_8bbf2_row15_col2, #T_8bbf2_row15_col3, #T_8bbf2_row15_col4, #T_8bbf2_row16_col1, #T_8bbf2_row16_col2, #T_8bbf2_row16_col3, #T_8bbf2_row16_col4, #T_8bbf2_row17_col1, #T_8bbf2_row17_col2, #T_8bbf2_row17_col4, #T_8bbf2_row18_col1, #T_8bbf2_row18_col2, #T_8bbf2_row18_col4, #T_8bbf2_row19_col1, #T_8bbf2_row19_col2, #T_8bbf2_row19_col3, #T_8bbf2_row19_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8bbf2_row4_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8bbf2_row17_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_8bbf2_row18_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8bbf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bbf2_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_8bbf2_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_8bbf2_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_8bbf2_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_8bbf2_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bbf2_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_8bbf2_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_8bbf2_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8bbf2_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8bbf2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_8bbf2_row0_col4" class="data row0 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row1" class="row_heading level0 row1" >SeniorCitizen</th>
#       <td id="T_8bbf2_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8bbf2_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8bbf2_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_8bbf2_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_8bbf2_row1_col4" class="data row1 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row2" class="row_heading level0 row2" >Partner</th>
#       <td id="T_8bbf2_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_8bbf2_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_8bbf2_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8bbf2_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_8bbf2_row2_col4" class="data row2 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row3" class="row_heading level0 row3" >Dependents</th>
#       <td id="T_8bbf2_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_8bbf2_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_8bbf2_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8bbf2_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_8bbf2_row3_col4" class="data row3 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row4" class="row_heading level0 row4" >tenure</th>
#       <td id="T_8bbf2_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_8bbf2_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_8bbf2_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_8bbf2_row4_col3" class="data row4 col3" >72</td>
#       <td id="T_8bbf2_row4_col4" class="data row4 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row5" class="row_heading level0 row5" >PhoneService</th>
#       <td id="T_8bbf2_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_8bbf2_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_8bbf2_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_8bbf2_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_8bbf2_row5_col4" class="data row5 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row6" class="row_heading level0 row6" >MultipleLines</th>
#       <td id="T_8bbf2_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_8bbf2_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_8bbf2_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_8bbf2_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_8bbf2_row6_col4" class="data row6 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row7" class="row_heading level0 row7" >InternetService</th>
#       <td id="T_8bbf2_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_8bbf2_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_8bbf2_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_8bbf2_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_8bbf2_row7_col4" class="data row7 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row8" class="row_heading level0 row8" >OnlineSecurity</th>
#       <td id="T_8bbf2_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_8bbf2_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_8bbf2_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_8bbf2_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_8bbf2_row8_col4" class="data row8 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row9" class="row_heading level0 row9" >OnlineBackup</th>
#       <td id="T_8bbf2_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_8bbf2_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_8bbf2_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_8bbf2_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_8bbf2_row9_col4" class="data row9 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row10" class="row_heading level0 row10" >DeviceProtection</th>
#       <td id="T_8bbf2_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_8bbf2_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_8bbf2_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_8bbf2_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_8bbf2_row10_col4" class="data row10 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row11" class="row_heading level0 row11" >TechSupport</th>
#       <td id="T_8bbf2_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_8bbf2_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_8bbf2_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_8bbf2_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_8bbf2_row11_col4" class="data row11 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_8bbf2_level0_row12" class="row_heading level0 row12" >StreamingTV</th>
#       <td id="T_8bbf2_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_8bbf2_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_8bbf2_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_8b

# %% [markdown]
# Determine Predictor and Target

# %%
X = df.drop('Churn',axis='columns')
y = df['Churn']

# %%
X.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 6602       1              0        1           1  0.549296             1
# 5434       0              0        0           1  0.450704             1
# 2029       0              0        1           0  0.929577             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 6602              1                1               0             1
# 5434              1                1               1             0
# 2029              0                1               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 6602                 1            0            1                0         0
# 5434                 1            0            0                1         0
# 2029                 0            0            0                1         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 6602                 1              1        0.777114      0.449642
# 5434                 1              0        0.766667      0.375762
# 2029                 1              1        0.719900      0.696671

# %%
y.sample(3)
# Out:
# 3888    1
# 4057    0
# 1260    0
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 19)

# %%
X_test.shape
# Out:
# (1407, 19)

# %% [markdown]
# Building the ANN Model

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(15, input_shape=(19,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7239 - loss: 0.5376
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7513 - loss: 0.4597
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7913 - loss: 0.4320
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7950 - loss: 0.4244
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7972 - loss: 0.4202
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7975 - loss: 0.4171
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7980 - loss: 0.4151
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7986 - loss: 0.4149
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8041 - loss: 0.4136
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8046 - loss: 0.4123
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8028 - loss: 0.4127
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8032 - loss: 0.4110
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8060 - loss: 0.4104
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8060 - loss: 0.4098
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8059 - loss: 0.4090
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8087 - loss: 0.4093
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8064 - loss: 0.4089
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8062 - loss: 0.4093
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8069 - loss: 0.4070
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8068 - loss: 0.4072
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8091 - loss: 0.4066
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8075 - loss: 0.4067
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8087 - loss: 0.4063
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8092 - loss: 0.4057
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8100 - loss: 0.4057
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8117 - loss: 0.4047
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8110 - loss: 0.4042
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8121 - loss: 0.4037
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8117 - loss: 0.4044
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8116 - loss: 0.4038
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8117 - loss: 0.4035
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8121 - loss: 0.4025
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8123 - loss: 0.4026
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8121 - loss: 0.4017
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8126 - loss: 0.4019
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8112 - loss: 0.4021
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8123 - loss: 0.4012
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8162 - loss: 0.4001
# Epoch 39/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8132 - loss: 0.4000
# Epoch 40/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8142 - loss: 0.4004
# Epoch 41/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8148 - loss: 0.4000
# Epoch 42/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8126 - loss: 0.4006
# Epoch 43/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8153 - loss: 0.3998
# Epoch 44/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8148 - loss: 0.3984
# Epoch 45/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8165 - loss: 0.3979
# Epoch 46/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8158 - loss: 0.3977
# Epoch 47/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8167 - loss: 0.3983
# Epoch 48/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8158 - loss: 0.3980
# Epoch 49/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8133 - loss: 0.3979
# Epoch 50/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8132 - loss: 0.3981
# Epoch 51/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8133 - loss: 0.3972
# Epoch 52/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8164 - loss: 0.3963
# Epoch 53/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8144 - loss: 0.3972
# Epoch 54/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8149 - loss: 0.3967
# Epoch 55/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8178 - loss: 0.3957
# Epoch 56/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8174 - loss: 0.3964
# Epoch 57/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.3956
# Epoch 58/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8137 - loss: 0.3961
# Epoch 59/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8181 - loss: 0.3950
# Epoch 60/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8162 - loss: 0.3955
# Epoch 61/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8162 - loss: 0.3951
# Epoch 62/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8171 - loss: 0.3949
# Epoch 63/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8172 - loss: 0.3946
# Epoch 64/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8172 - loss: 0.3936
# Epoch 65/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8162 - loss: 0.3928
# Epoch 66/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8169 - loss: 0.3935
# Epoch 67/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8183 - loss: 0.3940
# Epoch 68/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8183 - loss: 0.3931
# Epoch 69/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8188 - loss: 0.3940
# Epoch 70/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8178 - loss: 0.3929
# Epoch 71/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8183 - loss: 0.3930
# Epoch 72/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8183 - loss: 0.3919
# Epoch 73/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8187 - loss: 0.3919
# Epoch 74/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8185 - loss: 0.3924
# Epoch 75/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8167 - loss: 0.3928
# Epoch 76/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8196 - loss: 0.3916
# Epoch 77/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8165 - loss: 0.3912
# Epoch 78/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8188 - loss: 0.3915
# Epoch 79/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8199 - loss: 0.3918
# Epoch 80/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8192 - loss: 0.3909
# Epoch 81/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8190 - loss: 0.3911
# Epoch 82/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8185 - loss: 0.3907
# Epoch 83/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8219 - loss: 0.3905
# Epoch 84/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8210 - loss: 0.3899
# Epoch 85/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8210 - loss: 0.3897
# Epoch 86/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8204 - loss: 0.3900
# Epoch 87/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8220 - loss: 0.3897
# Epoch 88/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8208 - loss: 0.3894
# Epoch 89/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8201 - loss: 0.3905
# Epoch 90/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8235 - loss: 0.3889
# Epoch 91/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8204 - loss: 0.3893
# Epoch 92/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8212 - loss: 0.3887
# Epoch 93/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8220 - loss: 0.3886
# Epoch 94/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8219 - loss: 0.3883
# Epoch 95/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8224 - loss: 0.3890
# Epoch 96/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8242 - loss: 0.3873
# Epoch 97/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8219 - loss: 0.3888
# Epoch 98/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8201 - loss: 0.3879
# Epoch 99/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8203 - loss: 0.3876
# Epoch 100/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8213 - loss: 0.3868

# %% [markdown]
# Model Evaluation

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7775 - loss: 0.4660
# [0.4659682810306549, 0.7775408625602722]

# %% [markdown]
# Model Metrics

# %%
from sklearn.metrics import confusion_matrix , classification_report

# %%
yp = model.predict(X_test)

y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       999
#            1       0.63      0.56      0.59       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.71      0.72      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
report = classification_report(y_test, y_pred, output_dict=True)
rep = pd.DataFrame(report).transpose()

# Create a heatmap of the classification report
plt.figure(figsize=(10, 6))
sns.heatmap(df.iloc[:-1, :4], annot=True, cmap='Blues')
plt.title('Classification Report')
plt.show()

# %%
# Extract metrics for each class
classes = [str(key) for key in range(len(report) - 3)]  # Extract class labels
precision = [report[key]['precision'] for key in classes]
recall = [report[key]['recall'] for key in classes]
f1_score = [report[key]['f1-score'] for key in classes]

# %%
# Plotting the metrics using a bar chart
plt.figure(figsize=(12, 6))
barWidth = 0.25
r1 = range(len(classes))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, precision, color='#4b0082', width=barWidth, edgecolor='grey', label='Precision')
plt.bar(r2, recall, color='#f0f8ff', width=barWidth, edgecolor='grey', label='Recall')
plt.bar(r3, f1_score, color='#ff7f50', width=barWidth, edgecolor='grey', label='F1-score')

plt.xlabel('Class', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(classes))], classes)
plt.legend()
plt.title("Classification Report Metrics")
plt.show()

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
